# %% [markdown]
# ## Importar librerías

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
url='https://data.cityofnewyork.us/resource/h9gi-nx95.csv'

# %%
df=pd.read_csv(url)

# %%
df.sample(5)
# Out:
#                   crash_date crash_time   borough  zip_code   latitude  \
# 785  2019-10-02T00:00:00.000      14:11       NaN       NaN  40.740093
# 234  2019-10-08T00:00:00.000       7:20  BROOKLYN   11205.0  40.694576
# 167  2019-10-08T00:00:00.000      23:30    QUEENS   11427.0  40.726707
# 315  2019-10-19T00:00:00.000      20:50       NaN       NaN  40.639576
# 508  2019-10-11T00:00:00.000      16:30       NaN       NaN  40.748512
#
#      longitude                      location  \
# 785 -73.899860   POINT (-73.89986 40.740093)
# 234 -73.956150   POINT (-73.95615 40.694576)
# 167 -73.747520   POINT (-73.74752 40.726707)
# 315 -73.998146  POINT (-73.998146 40.639576)
# 508 -73.988720   POINT (-73.98872 40.748512)
#
#                        on_street_name off_street_name cross_street_name  ...  \
# 785  BROOKLYN QUEENS EXPRESSWAY                   NaN               NaN  ...
# 234  BEDFORD AVENUE                     MYRTLE AVENUE               NaN  ...
# ...

# %%
df.dtypes
# Out:
# crash_date                        object
# crash_time                        object
# borough                           object
# zip_code                         float64
# latitude                         float64
# longitude                        float64
# location                          object
# on_street_name                    object
# off_street_name                   object
# cross_street_name                 object
# number_of_persons_injured          int64
# number_of_persons_killed           int64
# number_of_pedestrians_injured      int64
# number_of_pedestrians_killed       int64
# number_of_cyclist_injured          int64
# number_of_cyclist_killed           int64
# number_of_motorist_injured         int64
# number_of_motorist_killed          int64
# contributing_factor_vehicle_1     object
# contributing_factor_vehicle_2     object
# contributing_factor_vehicle_3     object
# contributing_factor_vehicle_4     object
# contributing_factor_vehicle_5     object
# ...

# %% [markdown]
# ¿Cómo sé el largo del df (número de filas)?

# %%
df.shape
# Out:
# (1000, 29)

# %%
len(df)
# Out:
# 1000

# %% [markdown]
# Me insteresa saber si hay filas con NaN

# %%
df.isna().sum()
# Out:
# crash_date                         0
# crash_time                         0
# borough                          380
# zip_code                         380
# latitude                         100
# longitude                        100
# location                         100
# on_street_name                   218
# off_street_name                  509
# cross_street_name                782
# number_of_persons_injured          0
# number_of_persons_killed           0
# number_of_pedestrians_injured      0
# number_of_pedestrians_killed       0
# number_of_cyclist_injured          0
# number_of_cyclist_killed           0
# number_of_motorist_injured         0
# number_of_motorist_killed          0
# contributing_factor_vehicle_1      6
# contributing_factor_vehicle_2    135
# contributing_factor_vehicle_3    939
# contributing_factor_vehicle_4    977
# contributing_factor_vehicle_5    993
# collision_id                       0
# vehicle_type_code1                 7
# ...

# %% [markdown]
# ¿Cómo me aseguro que los _collision_id_ son únicos?

# %%
df['collision_id'].nunique()
# Out:
# 1000

# %% [markdown]
# ### Trabajo con filtro

# %%
df['borough'].value_counts()
# Out:
# QUEENS           213
# BROOKLYN         183
# MANHATTAN        114
# BRONX             97
# STATEN ISLAND     13
# Name: borough, dtype: int64

# %% [markdown]
# Para filtrar solo _QUEENS_

# %% [markdown]
# 1) opción "filtro largo"

# %%
df[df['borough']=='QUEENS']
# Out:
#                   crash_date crash_time borough  zip_code   latitude  \
# 0    2019-10-21T00:00:00.000       9:30  QUEENS   11416.0  40.683453
# 9    2019-10-24T00:00:00.000       7:05  QUEENS   11375.0  40.715073
# 10   2019-10-22T00:00:00.000      17:00  QUEENS   11423.0  40.720352
# 11   2019-10-18T00:00:00.000      14:20  QUEENS   11385.0  40.695070
# 13   2019-10-16T00:00:00.000      18:45  QUEENS   11422.0  40.665245
# 18   2019-10-04T00:00:00.000       0:33  QUEENS   11433.0  40.699990
# 28   2019-10-09T00:00:00.000      17:38  QUEENS   11432.0  40.714542
# 33   2019-10-18T00:00:00.000      16:54  QUEENS   11419.0  40.684383
# 36   2019-10-04T00:00:00.000       8:16  QUEENS   11418.0  40.704680
# 37   2019-10-04T00:00:00.000      19:41  QUEENS   11420.0  40.682537
# 39   2019-10-22T00:00:00.000       2:12  QUEENS   11412.0  40.691210
# 45   2019-10-30T00:00:00.000       8:00  QUEENS   11354.0  40.766075
# 51   2019-10-02T00:00:00.000      14:00  QUEENS   11366.0  40.732830
# ...

# %% [markdown]
# supongamos que quiero la columna fecha y ubicación de Queens

# %%
df.loc[df['borough']=='QUEENS',['crash_date','location']].head(2)
# Out:
#                 crash_date                      location
# 0  2019-10-21T00:00:00.000  POINT (-73.855606 40.683453)
# 9  2019-10-24T00:00:00.000   POINT (-73.82722 40.715073)

# %% [markdown]
# 2da forma: usar una condición, definida como **variable**

# %%
condicion_1=df['borough']=='QUEENS'

# %%
df[condicion_1].head(2)
# Out:
#                 crash_date crash_time borough  zip_code   latitude  longitude  \
# 0  2019-10-21T00:00:00.000       9:30  QUEENS   11416.0  40.683453 -73.855606
# 9  2019-10-24T00:00:00.000       7:05  QUEENS   11375.0  40.715073 -73.827220
#
#                        location                    on_street_name  \
# 0  POINT (-73.855606 40.683453)  ROCKAWAY BOULEVARD
# 9   POINT (-73.82722 40.715073)  126 STREET
#
#   off_street_name cross_street_name  ...   contributing_factor_vehicle_2  \
# 0       97 AVENUE               NaN  ...                     Unspecified
# 9  UNION TURNPIKE               NaN  ...  Driver Inattention/Distraction
#
#    contributing_factor_vehicle_3  contributing_factor_vehicle_4  \
# 0                            NaN                            NaN
# 9                            NaN                            NaN
#
#    contributing_factor_vehicle_5  collision_id  \
# 0                            NaN       4226874
# ...

# %% [markdown]
# Supongamos que quiero ahora dos condiciones

# %%
condicion_2=df['borough']=='BRONX'

# %% [markdown]
# ¿Cómo filtro los casos que son de Queens **o** del bronx

# %%
df[condicion_1|condicion_2]
# Out:
#                   crash_date crash_time borough  zip_code   latitude  \
# 0    2019-10-21T00:00:00.000       9:30  QUEENS   11416.0  40.683453
# 2    2019-10-04T00:00:00.000      21:30   BRONX   10451.0  40.815437
# 4    2019-10-29T00:00:00.000       8:46   BRONX   10457.0  40.840420
# 7    2019-10-13T00:00:00.000      12:50   BRONX   10455.0  40.814934
# 9    2019-10-24T00:00:00.000       7:05  QUEENS   11375.0  40.715073
# 10   2019-10-22T00:00:00.000      17:00  QUEENS   11423.0  40.720352
# 11   2019-10-18T00:00:00.000      14:20  QUEENS   11385.0  40.695070
# 13   2019-10-16T00:00:00.000      18:45  QUEENS   11422.0  40.665245
# 18   2019-10-04T00:00:00.000       0:33  QUEENS   11433.0  40.699990
# 21   2019-10-16T00:00:00.000      23:30   BRONX   10461.0  40.856842
# 28   2019-10-09T00:00:00.000      17:38  QUEENS   11432.0  40.714542
# 31   2019-10-15T00:00:00.000       0:00   BRONX   10469.0  40.877720
# 33   2019-10-18T00:00:00.000      16:54  QUEENS   11419.0  40.684383
# ...

# %%
df_queen=df[condicion_1]

# %%
df_queen['borough'].value_counts()
# Out:
# QUEENS    213
# Name: borough, dtype: int64

# %%
df.groupby(['borough'])['collision_id'].nunique()
# Out:
# borough
# BRONX             97
# BROOKLYN         183
# MANHATTAN        114
# QUEENS           213
# STATEN ISLAND     13
# Name: collision_id, dtype: int64

# %% [markdown]
# ### Trabajo con fechas
